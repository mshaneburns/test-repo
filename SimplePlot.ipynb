# %% [markdown]
# # Test jupyter notebook
# I'm creating this to test [Binder](https://mybinder.org) so that others can open Jupiter notebooks in an online executable environment.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-3*np.pi,3*np.pi,1000)
y = np.sin(x)
z = np.cos(x)

plt.plot(x,y)
plt.plot(x,z)
plt.show()

# %% [markdown]
# Let's try and equation $E=mc^2$.
